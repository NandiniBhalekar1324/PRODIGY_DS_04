# %% [markdown]
# <h3>Task-03</h3>
#
# Build a decision tree classifier to predict whether a customer will purchase a product or service based on their demographic and behavioral data. Use a dataset such as the Bank Marketing dataset from the UCI Machine Learning Repository.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.preprocessing import OneHotEncoder  # For categorical encoding
from sklearn.pipeline import Pipeline  # For creating a pipeline (optional)
import matplotlib.pyplot as plt

# %%
# Load the Bank Marketing dataset
url = "C:\\Users\\Hp\\Downloads\\bank+marketing\\bank-additional\\bank-additional\\bank-additional.csv"
data = pd.read_csv(url, header=0, delimiter=";")

# %%
# Check for missing values
print(data.isnull().sum())

# Consider appropriate imputation techniques based on data characteristics
# (e.g., mean/median imputation, mode imputation)
# data.fillna(method='ffill', inplace=True)  # Replace with your chosen method
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
print(data.head())
# Out:
#    age          job  marital          education default  housing     loan  \
# 0   30  blue-collar  married           basic.9y      no      yes       no
# 1   39     services   single        high.school      no       no       no
# 2   25     services  married        high.school      no      yes       no
# 3   38     services  married           basic.9y      no  unknown  unknown
# 4   47       admin.  married  university.degree      no      yes       no
#
#      contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0   cellular   may         fri  ...         2    999         0  nonexistent
# 1  telephone   may         fri  ...         4    999         0  nonexistent
# 2  telephone   jun         wed  ...         1    999         0  nonexistent
# 3  telephone   jun         fri  ...         3    999         0  nonexistent
# 4   cellular   nov         mon  ...         1    999         0  nonexistent
#
# ...

# %%
data.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
data
# Out:
#       age          job  marital          education default  housing     loan  \
# 0      30  blue-collar  married           basic.9y      no      yes       no
# 1      39     services   single        high.school      no       no       no
# 2      25     services  married        high.school      no      yes       no
# 3      38     services  married           basic.9y      no  unknown  unknown
# 4      47       admin.  married  university.degree      no      yes       no
# ...   ...          ...      ...                ...     ...      ...      ...
# 4114   30       admin.  married           basic.6y      no      yes      yes
# 4115   39       admin.  married        high.school      no      yes       no
# 4116   27      student   single        high.school      no       no       no
# 4117   58       admin.  married        high.school      no       no       no
# 4118   34   management   single        high.school      no      yes       no
#
# ...

# %%
# Separate features and target
X = data.drop(columns=['y'])  # Replace 'purchase' with the actual target column name
y = data['y']  # Replace 'purchase' with the target column name

# Convert categorical variables to dummy/indicator variables (one-hot encoding)
X = pd.get_dummies(X)

# %%
X
# Out:
#       age  duration  campaign  pdays  previous  emp.var.rate  cons.price.idx  \
# 0      30       487         2    999         0          -1.8          92.893
# 1      39       346         4    999         0           1.1          93.994
# 2      25       227         1    999         0           1.4          94.465
# 3      38        17         3    999         0           1.4          94.465
# 4      47        58         1    999         0          -0.1          93.200
# ...   ...       ...       ...    ...       ...           ...             ...
# 4114   30        53         1    999         0           1.4          93.918
# 4115   39       219         1    999         0           1.4          93.918
# 4116   27        64         2    999         1          -1.8          92.893
# 4117   58       528         1    999         0           1.4          93.444
# 4118   34       175         1    999         0          -0.1          93.200
#
# ...

# %%
X = pd.get_dummies(X)
# Out:
#       age          job  marital          education default  housing     loan  \
# 0      30  blue-collar  married           basic.9y      no      yes       no
# 1      39     services   single        high.school      no       no       no
# 2      25     services  married        high.school      no      yes       no
# 3      38     services  married           basic.9y      no  unknown  unknown
# 4      47       admin.  married  university.degree      no      yes       no
# ...   ...          ...      ...                ...     ...      ...      ...
# 4114   30       admin.  married           basic.6y      no      yes      yes
# 4115   39       admin.  married        high.school      no      yes       no
# 4116   27      student   single        high.school      no       no       no
# 4117   58       admin.  married        high.school      no       no       no
# 4118   34   management   single        high.school      no      yes       no
#
# ...

# %%
X
# Out:
#       age  duration  campaign  pdays  previous  emp.var.rate  cons.price.idx  \
# 0      30       487         2    999         0          -1.8          92.893
# 1      39       346         4    999         0           1.1          93.994
# 2      25       227         1    999         0           1.4          94.465
# 3      38        17         3    999         0           1.4          94.465
# 4      47        58         1    999         0          -0.1          93.200
# ...   ...       ...       ...    ...       ...           ...             ...
# 4114   30        53         1    999         0           1.4          93.918
# 4115   39       219         1    999         0           1.4          93.918
# 4116   27        64         2    999         1          -1.8          92.893
# 4117   58       528         1    999         0           1.4          93.444
# 4118   34       175         1    999         0          -0.1          93.200
#
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Initialize and train the Decision Tree Classifier
model = DecisionTreeClassifier(random_state=42)
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
# Make predictions on the test set
y_pred = model.predict(X_test)
# Out:
# Accuracy: 0.88
# Classification Report:
#               precision    recall  f1-score   support
#
#           no       0.95      0.92      0.93      1105
#          yes       0.44      0.55      0.49       131
#
#     accuracy                           0.88      1236
#    macro avg       0.69      0.73      0.71      1236
# weighted avg       0.89      0.88      0.88      1236
#
#
# Confusion Matrix:
#  [[1015   90]
#  [  59   72]]

# %%
# Calculate accuracy and print the classification report
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 0.88
#
# Classification Report:
#               precision    recall  f1-score   support
#
#           no       0.95      0.92      0.93      1105
#          yes       0.44      0.55      0.49       131
#
#     accuracy                           0.88      1236
#    macro avg       0.69      0.73      0.71      1236
# weighted avg       0.89      0.88      0.88      1236
#
#
# Confusion Matrix:
# [[1015   90]
#  [  59   72]]

# %%
# Visualize the Decision Tree
plt.figure(figsize=(20, 10))
from sklearn.tree import plot_tree
plot_tree(model, filled=True, feature_names=X.columns, class_names=['No', 'Yes'])
plt.show()
